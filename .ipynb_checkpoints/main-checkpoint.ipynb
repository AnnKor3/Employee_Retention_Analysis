# %% [markdown]
# import import_ipynb

# %%
pwd
# Out:
# 'C:\\Users\\annam\\HR\\Employee Retention Analysis'

# %%
import ipynb

# %%
import data_processing.processing as processing

# %%
processing.load_data()
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
ls
# Out:
#  Volume in drive C is Windows_OS
#  Volume Serial Number is 22F3-1F1E
#
#  Directory of C:\Users\annam\HR\Employee Retention Analysis
#
# 02/05/2023  18:38    <DIR>          .
# 02/05/2023  10:11    <DIR>          ..
# 02/05/2023  18:20    <DIR>          .ipynb_checkpoints
# 02/05/2023  17:49    <DIR>          data
# 02/05/2023  18:35    <DIR>          data_processing
# 02/05/2023  18:36               474 main.py
# 02/05/2023  17:44    <DIR>          model_training
# 02/05/2023  17:50    <DIR>          notebooks_demo
# 02/05/2023  17:48    <DIR>          outputs
# 02/05/2023  18:38            26,468 Untitled.ipynb
#                2 File(s)         26,942 bytes
#                8 Dir(s)  137,643,548,672 bytes free

# %%
# %run -i main.py
# Out:
#       Age  DailyRate  DistanceFromHome  Education  EmployeeCount  \
# 1041   28        866                 5          3              1
# 184    53       1084                13          2              1
# 1222   24        240                22          1              1
# 67     45       1339                 7          3              1
# 220    36       1396                 5          2              1
# ...   ...        ...               ...        ...            ...
# 1047   33        430                 7          3              1
# 331    27        210                 1          1              1
# 323    28       1157                 2          4              1
# 654    39       1383                 2          3              1
# 1110   35        104                 2          3              1
#
#       EmployeeNumber  EnvironmentSatisfaction  HourlyRate  JobInvolvement  \
# 1041            1469                        4          84               3
# ...

# %%
X_train, X_test, y_train, y_test = processing.get_split_data()

# %%
import model_training.model as model

# %%
X_test, shap_values = model.training(X_train, y_train, X_test, y_test)

# %%
X_test = processing.get_top10_features(X_test, shap_values)

# %%
X_test[X_test['Prediction']==1]
# Out:
#       Age  DailyRate  DistanceFromHome  Education  EmployeeCount  \
# 51     28       1434                 5          4              1
# 363    33        350                 5          3              1
# 892    19        504                10          3              1
# 777    21       1334                10          3              1
# 422    19        489                 2          2              1
# 1311   18       1431                14          3              1
# 921    28        791                 1          4              1
# 1057   29        115                13          3              1
# 296    18        230                 3          3              1
# 323    28       1157                 2          4              1
# 1110   35        104                 2          3              1
#
#       EmployeeNumber  EnvironmentSatisfaction  HourlyRate  JobInvolvement  \
# 51                65                        3          50               3
# ...

# %%
shap_values
# Out:
# array([[ 0.137132  , -0.01433013, -0.14130428, ...,  0.00268978,
#          0.22011454,  0.        ],
#        [-0.15933151, -0.10865409,  0.19035462, ..., -0.00357936,
#         -0.11718029,  0.        ],
#        [ 0.37572046,  0.07753321,  0.43769084, ..., -0.01225322,
#         -0.14693262,  0.        ],
#        ...,
#        [ 0.33702472, -0.05130333, -0.216069  , ..., -0.02513093,
#         -0.11443606,  0.        ],
#        [-0.12310763, -0.04504672, -0.12115103, ...,  0.01800051,
#         -0.07530855,  0.        ],
#        [-0.20099819,  0.1197947 , -0.29499144, ...,  0.00158423,
#         -0.12716088,  0.        ]])

# %%
model.get_top10_features(X_test, shap_values)
# Out:
#       Age  DailyRate  DistanceFromHome  Education  EmployeeCount  \
# 1041   28        866                 5          3              1
# 184    53       1084                13          2              1
# 1222   24        240                22          1              1
# 67     45       1339                 7          3              1
# 220    36       1396                 5          2              1
# ...   ...        ...               ...        ...            ...
# 1047   33        430                 7          3              1
# 331    27        210                 1          1              1
# 323    28       1157                 2          4              1
# 654    39       1383                 2          3              1
# 1110   35        104                 2          3              1
#
#       EmployeeNumber  EnvironmentSatisfaction  HourlyRate  JobInvolvement  \
# 1041            1469                        4          84               3
# ...

# %%
import pandas as pd

# %%
pd.set_option('display.max_colwidth', 150)
pd.DataFrame(X_test['top 10 features']).head()
# Out:
#                                                                                                                                             top 10 features
# 1041  Age: 0.13713200288559876, Department_Sales: 0.190557755317269, MaritalStatus_Single: 0.22011454392282212, StockOptionLevel: 0.333383864750985, Job...
# 184   EducationField_Life Sciences: 0.05518165428547577, YearsInCurrentRole: 0.08686151519018985, TotalWorkingYears: 0.15321894965874733, DistanceFromHo...
# 1222  YearsAtCompany: 0.3295317169837886, Age: 0.3757204589793885, YearsWithCurrManager: 0.3857004786665678, DistanceFromHome: 0.43769083749984805, Mont...
# 67    EnvironmentSatisfaction: 0.06101941106419438, YearsAtCompany: 0.13519030395809856, YearsInCurrentRole: 0.14648957040174962, YearsWithCurrManager: ...
# 220   Gender_Male: 0.06519865271626171, JobRole_Laboratory Technician: 0.09629128779258192, MaritalStatus_Single: 0.16687747291772842, StockOptionLevel:...
